# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
import re
import string

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
movie_df = pd.read_csv("/content/movies.csv")
movie_df.head(10)
# Out:
#                  title                                           overview  \
# 0                Ariel  After the coal mine he works at closes and his...
# 1  Shadows in Paradise  Nikander, a rubbish collector and would-be ent...
# 2           Four Rooms  It's Ted the Bellhop's first night on the job....
# 3       Judgment Night  Four young friends, while taking a shortcut en...
# 4            Star Wars  Princess Leia is captured and held hostage by ...
# 5         Finding Nemo  Nemo, an adventurous young clownfish, is unexp...
# 6         Forrest Gump  A man with a low IQ has accomplished great thi...
# 7      American Beauty  Lester Burnham, a depressed suburban father in...
# 8         Citizen Kane  Newspaper magnate Charles Foster Kane is taken...
# 9   Dancer in the Dark  Selma, a Czech immigrant on the verge of blind...
#
#                                         genre
# 0     ['Drama', 'Comedy', 'Romance', 'Crime']
# 1              ['Drama', 'Comedy', 'Romance']
# 2                                  ['Comedy']
# 3             ['Action', 'Crime', 'Thriller']
# 4  ['Adventure', 'Action', 'Science Fiction']
# 5                     ['Animation', 'Family']
# 6              ['Comedy', 'Drama', 'Romance']
# 7                                   ['Drama']
# 8                        ['Mystery', 'Drama']
# 9                          ['Drama', 'Crime']

# %%
movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9466 entries, 0 to 9465
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     9466 non-null   object
#  1   overview  9465 non-null   object
#  2   genre     9466 non-null   object
# dtypes: object(3)
# memory usage: 222.0+ KB

# %%
movie_df.isnull().sum()
# Out:
# title       0
# overview    1
# genre       0
# dtype: int64

# %%
movie_df.dropna(inplace = True)

# %%
movie_df.isnull().sum()
# Out:
# title       0
# overview    0
# genre       0
# dtype: int64

# %%
movie_df.rename(columns={
    'overview': 'plot',
}, inplace=True)

# %%
movie_df.head(20)
# Out:
#                                                 title  \
# 0                                               Ariel
# 1                                 Shadows in Paradise
# 2                                          Four Rooms
# 3                                      Judgment Night
# 4                                           Star Wars
# 5                                        Finding Nemo
# 6                                        Forrest Gump
# 7                                     American Beauty
# 8                                        Citizen Kane
# 9                                  Dancer in the Dark
# 10                                  The Fifth Element
# 11                                         Metropolis
# 12                                 My Life Without Me
# 13  Pirates of the Caribbean: The Curse of the Bla...
# 14                                  Kill Bill: Vol. 1
# 15                                            Jarhead
# 16                                            9 Songs
# 17                                     Apocalypse Now
# 18                                         Unforgiven
# 19              Eternal Sunshine of the Spotless Mind
#
#                                                  plot  \
# 0   After the coal mine he works at closes and his...
# 1   Nikander, a rubbish collector and would-be ent...
# 2   It's Ted the Bellhop's first night on the job....
# 3   Four young friends, while taking a shortcut en...
# 4   Princess Leia is captured and held hostage by ...
# 5   Nemo, an adventurous young clownfish, is unexp...
# 6   A man with a low IQ has accomplished great thi...
# 7   Lester Burnham, a depressed suburban father in...
# 8   Newspaper magnate Charles Foster Kane is taken...
# 9   Selma, a Czech immigrant on the verge of blind...
# 10  In 2257, a taxi driver is unintentionally give...
# 11  In a futuristic city sharply divided between t...
# 12  A fatally ill mother with only two months to l...
# 13  Jack Sparrow, a freewheeling 18th-century pira...
# 14  An assassin is shot by her ruthless employer, ...
# 15  Jarhead is a film about a US Marine Anthony Sw...
# 16  Matt, a young glaciologist, soars across the v...
# 17  At the height of the Vietnam war, Captain Benj...
# 18  William Munny is a retired, once-ruthless kill...
# 19  Joel Barish, heartbroken that his girlfriend u...
#
#                                                 genre
# 0             ['Drama', 'Comedy', 'Romance', 'Crime']
# 1                      ['Drama', 'Comedy', 'Romance']
# 2                                          ['Comedy']
# 3                     ['Action', 'Crime', 'Thriller']
# 4          ['Adventure', 'Action', 'Science Fiction']
# 5                             ['Animation', 'Family']
# 6                      ['Comedy', 'Drama', 'Romance']
# 7                                           ['Drama']
# 8                                ['Mystery', 'Drama']
# 9                                  ['Drama', 'Crime']
# 10  ['Adventure', 'Fantasy', 'Action', 'Thriller',...
# 11                       ['Drama', 'Science Fiction']
# 12                               ['Drama', 'Romance']
# 13                 ['Adventure', 'Fantasy', 'Action']
# 14                                ['Action', 'Crime']
# 15                                   ['Drama', 'War']
# 16                      ['Drama', 'Music', 'Romance']
# 17                                   ['Drama', 'War']
# 18                                        ['Western']
# 19            ['Science Fiction', 'Drama', 'Romance']

# %%
movie_df.dropna(subset=['genre', 'plot'], inplace=True)

# %%
movie_df.shape
# Out:
# (9465, 3)

# %%
def clean_text(text):
    text = text.lower()                                      # lowercase
    text = re.sub(r'\[.*?\]', '', text)                      # remove brackets
    text = re.sub(r'https?://\S+|www\.\S+', '', text)        # remove URLs
    text = re.sub(r'<.*?>+', '', text)                       # remove HTML
    text = text.translate(str.maketrans('','', string.punctuation)) # remove punctuation
    text = re.sub(r'\n', '', text)                           # remove newline
    text = re.sub(r'\w*\d\w*', '', text)                     # remove digits
    text = ' '.join(word for word in text.split() if word not in stop_words)  # remove stopwords
    return text

movie_df['clean_plot'] = movie_df['plot'].apply(clean_text)

# %%
movie_df
# Out:
#                              title  \
# 0                            Ariel
# 1              Shadows in Paradise
# 2                       Four Rooms
# 3                   Judgment Night
# 4                        Star Wars
# ...                            ...
# 9461  TAYLOR SWIFT | THE ERAS TOUR
# 9462               The Rat Catcher
# 9463                      The Swan
# 9464                        Poison
# 9465                 Sixty Minutes
#
#                                                    plot  \
# 0     After the coal mine he works at closes and his...
# 1     Nikander, a rubbish collector and would-be ent...
# 2     It's Ted the Bellhop's first night on the job....
# 3     Four young friends, while taking a shortcut en...
# 4     Princess Leia is captured and held hostage by ...
# ...                                                 ...
# 9461  The cultural phenomenon continues on the big s...
# 9462  In an English village, a reporter and a mechan...
# 9463  Two large, ignorant bullies ruthlessly pursue ...
# 9464  When a poisonous snake slithers onto an Englis...
# 9465  Desperate to keep custody of his daughter, a m...
#
#                                            genre  \
# 0        ['Drama', 'Comedy', 'Romance', 'Crime']
# 1                 ['Drama', 'Comedy', 'Romance']
# 2                                     ['Comedy']
# 3                ['Action', 'Crime', 'Thriller']
# 4     ['Adventure', 'Action', 'Science Fiction']
# ...                                          ...
# 9461                                   ['Music']
# 9462                                  ['Comedy']
# 9463                                   ['Drama']
# 9464                                  ['Comedy']
# 9465                                  ['Action']
#
#                                              clean_plot
# 0     coal mine works closes father commits suicide ...
# 1     nikander rubbish collector wouldbe entrepreneu...
# 2     ted bellhops first night joband hotels unusual...
# 3     four young friends taking shortcut en route lo...
# 4     princess leia captured held hostage evil imper...
# ...                                                 ...
# 9461  cultural phenomenon continues big screen immer...
# 9462  english village reporter mechanic listen ratca...
# 9463  two large ignorant bullies ruthlessly pursue s...
# 9464  poisonous snake slithers onto englishmans stom...
# 9465  desperate keep custody daughter mixed martial ...
#
# [9465 rows x 4 columns]

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
movie_df['genre_label'] = le.fit_transform(movie_df['genre'])

label_names = dict(zip(le.transform(le.classes_), le.classes_))

# %%
X = movie_df['clean_plot']
y = movie_df['genre_label']

# %%
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size = 0.2, random_state = 1)

# %%
Vectorizer = TfidfVectorizer(max_features = 5000, ngram_range=(1, 3))
X_train_vec = Vectorizer.fit_transform(X_train)
X_test_vec = Vectorizer.transform(X_test)

# %%
from sklearn.svm import LinearSVC
svc = LinearSVC()
svc.fit(X_train_vec, y_train)
# Out:
# LinearSVC()

# %%
y_pred = svc.predict(X_test_vec)

# %%
print("Accuracy of the model :", accuracy_score(y_test, y_pred))
# Out:
# Accuracy of the model : 0.0919175911251981

# %%
movie_df.head(1)
# Out:
#    title                                               plot  \
# 0  Ariel  After the coal mine he works at closes and his...
#
#                                      genre  \
# 0  ['Drama', 'Comedy', 'Romance', 'Crime']
#
#                                           clean_plot  genre_label
# 0  coal mine works closes father commits suicide ...         1065

# %%
movie_df['plot'][0]
# Out:
# 'After the coal mine he works at closes and his father commits suicide, a Finnish man leaves for the city to make a living but there, he is framed and imprisoned for various crimes.'

# %%
plot = 'After the coal mine he works at closes and his father commits suicide, a Finnish man leaves for the city to make a living but there, he is framed and imprisoned for various crimes.'
vec = Vectorizer.transform([plot])
predicted_genre_code = svc.predict(vec)
predicted_genre = le.inverse_transform([predicted_genre_code])
print("The predicted genre is : ", predicted_genre[0])
# Out:
# The predicted genre is :  ['Drama', 'Comedy', 'Romance', 'Crime']
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
def predict_genre(plot):
    # Step 1: Clean the input plot
    cleaned_plot = clean_text(plot)

    # Step 2: Vectorize the cleaned plot
    vectorized_plot = Vectorizer.transform([cleaned_plot])

    # Step 3: Predict encoded genre using the model
    predicted_label = svc.predict(vectorized_plot)[0]

    # Step 4: Convert encoded label back to genre name
    genre_name = le.inverse_transform([predicted_label])[0]

    return genre_name

# %%
new_plot = "A computer hacker named Neo discovers that the world he lives in is a simulated reality called the Matrix. With the help of mysterious rebels, he learns the truth and joins the fight to free humanity from an oppressive AI system that controls the simulated world."

predicted = predict_genre(new_plot)
print("Predicted Genre:", predicted)
# Out:
# Predicted Genre: ['Action', 'Adventure', 'Science Fiction']
